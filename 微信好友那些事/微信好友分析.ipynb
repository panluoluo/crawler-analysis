# %% [markdown]
# ### 入门示例

# %%
import itchat

itchat.auto_login()

itchat.send('好玩的itchat', toUserName='filehelper')
# Out:
# █
# Getting uuid of QR code.
# Downloading QR code.
# Please scan the QR code to log in.
# Please press confirm on your phone.
# Loading the contact, this may take a little while.
# Login successfully as 罗攀
# <ItchatReturnValue: {'BaseResponse': {'Ret': 0, 'ErrMsg': '请求成功', 'RawMsg': '请求成功'}, 'MsgID': '5738543168325686548', 'LocalID': '15466696311837'}>

# %% [markdown]
# ### 获取好友信息

# %%
friends = itchat.get_friends(update=True)
friends[0]
# Out:
# <User: {'MemberList': <ContactList: []>, 'UserName': '@23092c76cbafa4bc97cfe9469515ee9e3f07fed23a555a83dd1205a1794a2311', 'City': '常德', 'DisplayName': '', 'PYQuanPin': 'luopan', 'RemarkPYInitial': '', 'Province': '湖南', 'KeyWord': '', 'RemarkName': '', 'PYInitial': 'LP', 'EncryChatRoomId': '', 'Alias': '', 'Signature': '', 'NickName': '罗攀', 'RemarkPYQuanPin': '', 'HeadImgUrl': '/cgi-bin/mmwebwx-bin/webwxgeticon?seq=470110&username=@23092c76cbafa4bc97cfe9469515ee9e3f07fed23a555a83dd1205a1794a2311&skey=@crypt_dcefb455_6a36eabc0dff5e0765c71c0f4592dea3', 'UniFriend': 0, 'Sex': 1, 'AppAccountFlag': 0, 'VerifyFlag': 0, 'ChatRoomId': 0, 'HideInputBarFlag': 0, 'AttrStatus': 233575, 'SnsFlag': 49, 'MemberCount': 0, 'OwnerUin': 0, 'ContactFlag': 1, 'Uin': 2185378081, 'StarFriend': 0, 'Statues': 0, 'WebWxPluginSwitch': 0, 'HeadImgFlag': 1, 'IsOwner': 0}>

# %%
import csv
fp = open('friend.csv','w',newline='',encoding='utf-8')
writer = csv.writer(fp)

writer.writerow(['NickName','Sex','Province','City','Signature'])

for friend in friends[1:]:
    writer.writerow([friend['NickName'],friend['Sex'],friend['Province'],friend['City'],friend['Signature']])

# %% [markdown]
# ### 数据情况

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('friend.csv',encoding='utf-8')
data.head()
# Out:
#   NickName  Sex Province City            Signature
# 0       ☀️    2       湖北   武汉                  NaN
# 1       郭成    1       湖南   常德                  NaN
# 2       彭彬    1       云南   昆明                  啦啦啦
# 3     科莫呗比    1       湖南   常德                  NaN
# 4        Q    2       湖南   常德  如果再见不能红着脸   是否还能红着眼

# %% [markdown]
# ### 性别分析

# %%
sex = data.groupby('Sex')['Sex'].count()
sex
# Out:
# Sex
# 0     21
# 1    279
# 2    169
# Name: Sex, dtype: int64

# %%
from pyecharts import Pie

attr = ['外星人','男性','女性']

v = list(sex)
pie = Pie("微信好友性别分布",  width=900)
pie.add(
    "",
    attr,
    v,
    center=[50, 50],
    is_random=True,
    radius=[30, 75],
    rosetype="radius",
)
pie
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="a3092e03d4214c5eb045ff1b80689ba4" style="width:900px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_a3092e03d4214c5eb045ff1b80689ba4 = echarts.init(document.getElementById('a3092e03d4214c5eb045ff1b80689ba4'), 'light', {renderer: 'canvas'});
#
# var option_a3092e03d4214c5eb045ff1b80689ba4 = {
#     "title": [
#         {
#             "text": "\u5fae\u4fe1\u597d\u53cb\u6027\u522b\u5206\u5e03",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 1699050,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "pie",
#             "data": [
#                 {
#                     "name": "\u5916\u661f\u4eba",
#                     "value": 21.0
#                 },
#                 {
#                     "name": "\u7537\u6027",
#                     "value": 279.0
#                 },
#                 {
#                     "name": "\u5973\u6027",
#                     "value": 169.0
#                 }
#             ],
#             "radius": [
#                 "30%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "roseType": "radius",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "outside",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "seriesId": 1699050
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5916\u661f\u4eba",
#                 "\u7537\u6027",
#                 "\u5973\u6027"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "color": [
#         "#b2d235",
#         "#f6f5ec",
#         "#726930",
#         "#918597",
#         "#444693",
#         "#fab27b",
#         "#6e7074",
#         "#2f4554",
#         "#546570",
#         "#1d953f",
#         "#ef5b9c",
#         "#f05b72",
#         "#2a5caa",
#         "#d48265",
#         "#ac6767",
#         "#c4ccd3",
#         "#6950a1",
#         "#f47920",
#         "#bda29a",
#         "#6d8346",
#         "#c23531",
#         "#905a3d",
#         "#61a0a8",
#         "#ca8622",
#         "#749f83"
#     ]
# };
# myChart_a3092e03d4214c5eb045ff1b80689ba4.setOption(option_a3092e03d4214c5eb045ff1b80689ba4);
#
#     });
# </script>

# %% [markdown]
# ### 好友地区分布

# %%
data.head()
# Out:
#   NickName  Sex Province City            Signature
# 0       ☀️    2       湖北   武汉                  NaN
# 1       郭成    1       湖南   常德                  NaN
# 2       彭彬    1       云南   昆明                  啦啦啦
# 3     科莫呗比    1       湖南   常德                  NaN
# 4        Q    2       湖南   常德  如果再见不能红着脸   是否还能红着眼

# %%
new_data1 = data[data['Province'].notnull()]
new_data1
# Out:
#          NickName  Sex   Province  City  \
# 0              ☀️    2         湖北    武汉
# 1              郭成    1         湖南    常德
# 2              彭彬    1         云南    昆明
# 3            科莫呗比    1         湖南    常德
# 4               Q    2         湖南    常德
# 8            夏夜星空    2         湖南    常德
# 9            此号停用    2         湖南    常德
# 10              夏    1  Abu Dhabi   NaN
# 12             宋鹏    1         湖南    长沙
# 14            木头琪    2         湖南    长沙
# 15            龙望葵    2         湖南    常德
# 16            付鑫景    2         湖南    长沙
# 18            黄逸炀    1         浙江    温州
# 19             王品    1         湖南    长沙
# 20            瑀小刘    2         北京   NaN
# 21             睡袋    2         江苏    苏州
# 22             向往    1         广东    清远
# 23             刘卓    1         湖南    长沙
# 24             长天    1         湖南    长沙
# 25             羊锅    1         湖南    邵阳
# 26        赵乙颖 🏃 🕖    2         湖南    长沙
# 27             宝毓    1         广东    深圳
# 28            林立彬    1         广东    清远
# 29           awed    1         浙江    嘉兴
# 30       Mr.Robot    1         吉林    长春
# 31             天涯    1         湖南    长沙
# 32              王    1         山东    济南
# 33       bookbook    2         北京    朝阳
# 34            丁丁_    1         湖南    长沙
# 35    starmorning    1         上海    徐汇
# ..            ...  ...        ...   ...
# 433           Cxy    1         山东    聊城
# 434           铁皮羊    1         江苏    苏州
# 435           😊开心    2         湖南    长沙
# 436        『夜＆弦月』    2         河北    承德
# 437           李十六    1         湖南    长沙
# 438          吃瓜群众    1         湖南    长沙
# 440             木    2       Lyon   NaN
# 441          ling    2         广东    广州
# 442           @,@    1         海南    儋州
# 444       H&amp;Y    1         江苏    淮安
# 445           胡振南    1         湖南    长沙
# 446  双马尾િ😄ી元气7777    2         江苏    南京
# 448            海风    1         广东    深圳
# 450           千百度    1         上海  浦东新区
# 451       Love.YY    2         上海    闸北
# 452      super胖胖祥    1         浙江    杭州
# 454        natule    1         湖南    长沙
# 455         jlzoa    2         广东    深圳
# 456            等枝    1         河南    信阳
# 457           刘阿敏    2         河南    信阳
# 458       Leopard    1         山西    太原
# 459          Ivan    2         湖南    长沙
# 461           醉时光    1         河南    安阳
# 462           吱~夏    2         湖南    怀化
# 463    AAaa安乡德牌童装    2         湖南    常德
# 464           X.Q    2         湖南    常德
# 465         黎奕晖๑~    2         湖南    长沙
# 466         👑 何羽原    2         湖南    长沙
# 467    doxi Diiee    2         浙江    宁波
# 468       SWAITML    1         山东    潍坊
#
#                                              Signature
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  啦啦啦
# 3                                                  NaN
# 4                                  如果再见不能红着脸   是否还能红着眼
# 8                                                  NaN
# 9                                       做自己让以后的自己感谢的事！
# 10                                                 NaN
# 12                                                 NaN
# 14                                          青春荒唐，不负自己。
# 15                                                  ……
# 16                                                 NaN
# 18                                           觉得苦那就吃一颗糖
# 19                                           幸福与感恩同行……
# 20                                                 NaN
# 21                                       人意烂漫，只向桃花开二分。
# 22                                                 NaN
# 23                                                心累……
# 24                                     夫学者载籍极博，尤考信于六艺。
# 25                                     (￣ε(#￣)☆╰╮(ಥ_ಥ)
# 26                                                 NaN
# 27                                          让优秀成为一种习惯！
# 28                                            听得见叶儿声声降
# 29                          我觉得人生就是要经历，我需要一段独属于我自己的时光。
# 30                                                 NaN
# 31                                                 NaN
# 32                                                 NaN
# 33                                          没有意义，要寻找意义
# 34                      一身诗意千寻瀑，万古人间四月天。最是人间留不住朱颜辞镜花辞树
# 35                                        Mind reform!
# ..                                                 ...
# 433                                               实干兴邦
# 434                                                NaN
# 435                                你要变得强大，才能保护好自己和你爱的人
# 436                                               君且随意
# 437                                           滚蛋吧，2018
# 438                                        18390219162
# 440                                                NaN
# 441  one by one,  step by step. (每天进步一丢丢！<span clas...
# 442                             那些曾让你哭的事，总有一天你会笑着说出来……
# 444                                                NaN
# 445                                                NaN
# 446                                                NaN
# 448                         关注过程，享受生活\n上半场专注事业，下半场回归家庭
# 450                                                NaN
# 451                                    But you didn't.
# 452                  做事之道，唯敬唯勤，持之以恒。to be a better me。
# 454                                         生活很苦  学会快乐
# 455                                              要瘦要有钱
# 456                                           A laity𓃟
# 457  女孩子一定要努力，想要的东西都很贵，想去的地方都很远<span class="emoji e...
# 458                                                NaN
# 459                                              怦然心动！
# 461                              人在得意时须沉得住傲气；失意时要忍得住火气
# 462                                       会笑的酒窝，会流泪的眼睛
# 463                                              陪你长大👪
# 464                                          所有的经历都是成长
# 465                               不骄不躁，未来可期～2019请多多指教🍭
# 466     不要低头 <span class="emoji emoji1f451"></span> 会掉
# 467                                     今天的一切就算突然我也不奇怪
# 468                                     非常努力，才会毫不费力。。。
#
# [381 rows x 5 columns]

# %%
province = data.groupby('Province')['Province'].count()
province
# Out:
# Province
# Abu Dhabi       1
# Arles           1
# Bali            1
# Berlin          1
# California      1
# Chiang Mai      1
# Clare           2
# Dublin          1
# Galway          1
# Luanda          1
# Lyon            1
# New York        1
# Paris           3
# Queensland      1
# Scotland        1
# Seoul           1
# Wicklow         1
# 上海             23
# 云南              2
# 内蒙古             3
# 北京             36
# 吉林              2
# 四川              3
# 天津              4
# 安徽              3
# 山东              9
# 山西              2
# 广东             41
# 广西              3
# 新疆              2
# 江苏             26
# 江西              2
# 河北              2
# 河南             38
# 浙江             12
# 海南              2
# 湖北             13
# 湖南            111
# 甘肃              2
# 福建              2
# 西藏              1
# 辽宁              3
# 重庆              5
# 陕西              5
# 青海              1
# 黑龙江             3
# Name: Province, dtype: int64

# %%
from pyecharts import Map

value = list(province)
attr = list(province.index)
map = Map("好友地区分布", width=1200, height=600)
map.add(
    "",
    attr,
    value,
    maptype="china",
    is_visualmap=True,
    visual_text_color="#000",
)
map
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'china': '/nbextensions/echarts-countries-js/china'
#         }
#     });
# </script>
#     <div id="4b266302b3164b90ad8fbf9808b4ad69" style="width:1200px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#
# var myChart_4b266302b3164b90ad8fbf9808b4ad69 = echarts.init(document.getElementById('4b266302b3164b90ad8fbf9808b4ad69'), 'light', {renderer: 'canvas'});
#
# var option_4b266302b3164b90ad8fbf9808b4ad69 = {
#     "title": [
#         {
#             "text": "\u597d\u53cb\u5730\u533a\u5206\u5e03",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 5620741,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "map",
#             "symbol": "circle",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "Abu Dhabi",
#                     "value": 1.0
#                 },
#                 {
#                     "name": "Arles",
#                     "value": 1.0
#                 },
#                 {
#                     "name": "Bali",
#                     "value": 1.0
#                 },
#                 {
#                     "name": "Berlin",
#                     "value": 1.0
#                 },
#                 {
#                     "name": "California",
#                     "value": 1.0
#                 },
#                 {
#                     "name": "Chiang Mai",
#                     "value": 1.0
#                 },
#                 {
#                     "name": "Clare",
#                     "value": 2.0
#                 },
#                 {
#                     "name": "Dublin",
#                     "value": 1.0
#                 },
#                 {
#                     "name": "Galway",
#                     "value": 1.0
#                 },
#                 {
#                     "name": "Luanda",
#                     "value": 1.0
#                 },
#                 {
#                     "name": "Lyon",
#                     "value": 1.0
#                 },
#                 {
#                     "name": "New York",
#                     "value": 1.0
#                 },
#                 {
#                     "name": "Paris",
#                     "value": 3.0
#                 },
#                 {
#                     "name": "Queensland",
#                     "value": 1.0
#                 },
#                 {
#                     "name": "Scotland",
#                     "value": 1.0
#                 },
#                 {
#                     "name": "Seoul",
#                     "value": 1.0
#                 },
#                 {
#                     "name": "Wicklow",
#                     "value": 1.0
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 23.0
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 2.0
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 3.0
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 36.0
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 2.0
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 3.0
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 4.0
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 3.0
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 9.0
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 2.0
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 41.0
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 3.0
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 2.0
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 26.0
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 2.0
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 2.0
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 38.0
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 12.0
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 2.0
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 13.0
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 111.0
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 2.0
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 2.0
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 1.0
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 3.0
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 5.0
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 5.0
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 1.0
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 3.0
#                 }
#             ],
#             "roam": true,
#             "showLegendSymbol": true
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca

# %% [markdown]
# ### 个性签名词云图

# %%
data.head()
# Out:
#   NickName  Sex Province City            Signature
# 0       ☀️    2       湖北   武汉                  NaN
# 1       郭成    1       湖南   常德                  NaN
# 2       彭彬    1       云南   昆明                  啦啦啦
# 3     科莫呗比    1       湖南   常德                  NaN
# 4        Q    2       湖南   常德  如果再见不能红着脸   是否还能红着眼

# %%
new_data2 = data[data['Signature'].notnull()]
new_data2.head()
# Out:
#    NickName  Sex Province City                           Signature
# 2        彭彬    1       云南   昆明                                 啦啦啦
# 4         Q    2       湖南   常德                 如果再见不能红着脸   是否还能红着眼
# 7   一袭水袖舞倾城    2      NaN  NaN                             谁的青春不迷茫
# 9      此号停用    2       湖南   常德                      做自己让以后的自己感谢的事！
# 13      l-半    0      NaN  NaN  推荐3个好友减5元，推荐5个好友减10元。新顾客9折，老顾客85折。

# %%
str_data = ''
for i in range(new_data2.shape[0]):
    str_data = str_data + new_data2.iloc[i,4]
str_data
# Out:
building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\luopan\AppData\Local\Temp\jieba.cache
# DEBUG:jieba:Loading model from cache C:\Users\luopan\AppData\Local\Temp\jieba.cache
# Loading model cost 0.605 seconds.
# DEBUG:jieba:Loading model cost 0.605 seconds.
# Prefix dict has been built succesfully.
# DEBUG:jieba:Prefix dict has been built succesfully.

# %%
label = []
attr = []
for item in tags:
    print(item[0]+'\t'+str(int(item[1]*1000)))
    label.append(item[0])
    attr.append(int(item[1]*1000))
# Out:
# span	347
# emoji	173
# class	100
# 人生	52
# 努力	46
# 自己	45
# emoji2747	45
# 快乐	45
# 生活	38
# go	27
# Never	27
# 平凡	27
# 欢迎	26
# 才能	24
# 总是	21
# 包子	21
# 不是	20
# 好友	19
# 美颜	19
# 幸运	18
# Mind	18
# DO	18
# RIGHT	18
# make	18
# my	18
# heart	18
# 浅醉	18
# 独醉	18
# 似茶	18
# 香亦似	18
# 2764	18
# sometimes	18
# 微信	18
# 公号	18
# Stay	18
# emoji1f49e	18
# me	18
# emoji1f451	18
# emoji1f353	18
# step	18
# 青春	18
# 浪费	17
# 梦想	17
# 美好	17
# 人间	16
# 咿呀	16
# 就是	16
# 唯心	16
# 交流	15
# 余生	15

# %%
from pyecharts import WordCloud

wordcloud = WordCloud(width=800, height=620)
wordcloud.add("", label[4:], attr[4:], word_size_range=[20, 100])
wordcloud
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'wordcloud': '/nbextensions/echarts/echarts-wordcloud.min'
#         }
#     });
# </script>
#     <div id="b371b2c2ea124dd49a17aa94d9056b8c" style="width:800px;height:620px;"></div>
#
#
# <script>
#     require(['echarts', 'wordcloud'], function(echarts) {
#
# var myChart_b371b2c2ea124dd49a17aa94d9056b8c = echarts.init(document.getElementById('b371b2c2ea124dd49a17aa94d9056b8c'), 'light', {renderer: 'canvas'});
#
# var option_b371b2c2ea124dd49a17aa94d9056b8c = {
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 8318071,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 20,
#                 100
#             ],
#             "data": [
#                 {
#                     "name": "\u52aa\u529b",
#                     "value": 46,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(53,19,156)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u81ea\u5df1",
#                     "value": 45,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(23,117,96)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "emoji2747",
#                     "value": 45,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(63,3,50)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5feb\u4e50",
#                     "value": 45,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(152,7,37)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u751f\u6d3b",
#                     "value": 38,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(80,68,152)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "go",
#                     "value": 27,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(87,39,39)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Never",
#                     "value": 27,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(21,71,67)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5e73\u51e1",
#                     "value": 27,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(57,59,51)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6b22\u8fce",
#                     "value": 26,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(96,143,51)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u624d\u80fd",
#                     "value": 24,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(144,93,59)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u603b\u662f",
#                     "value": 21,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(19,28,96)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5305\u5b50",
#                     "value": 21,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(139,157,118)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0d\u662f",
#                     "value": 20,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(6,50,88)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u597d\u53cb",
#                     "value": 19,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(132,117,37)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7f8e\u989c",
#                     "value": 19,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(152,87,160)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5e78\u8fd0",
#                     "value": 18,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(122,69,89)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Mind",
#                     "value": 18,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(4,37,143)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "DO",
#                     "value": 18,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(108,18,43)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "RIGHT",
#                     "value": 18,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(160,61,130)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "make",
#                     "value": 18,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(137,40,82)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "my",
#                     "value": 18,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(45,19,53)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "heart",
# LOG OUT!
# INFO:itchat:LOG OUT!
